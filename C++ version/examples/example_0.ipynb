# %%
import dynamic_color
args = [[], [6]]
res = dynamic_color.findPalette(*args)
res
# Out:
# [[0.996, 0.894, 0.702],
#  [7.789972789623789e-07, 0.5396187035087144, 1.0],
#  [1.0617892075543977e-06, 0.9620449580978864, 0.9552716726973457],
#  [0.9686746159703495, 0.30538653071953387, 0.16286367570878646],
#  [0.9994972493825381, 0.7825179535739738, 0.26323288425242697],
#  [1.7572367765374962e-07, 0.6099273409541868, 0.05897626529830833],
#  [0.9999999399150644, 0.41886367646543776, 0.9295480656897424]]

# %%
def show_palette(colors):
    import matplotlib.pyplot as plt
    fig, ax = plt.subplots()
    # set figure size
    fig.set_size_inches(18, 1)
    for i, color in enumerate(colors):
        ax.add_patch(plt.Rectangle((i, 0), 1, 1, color=color))
        ax.text(i+0.5, 0.5, i, ha='center', va='center', fontsize=8)
    ax.set_xlim(0, len(colors))
    ax.set_ylim(0, 1)
    ax.axis('off')
    plt.show()

show_palette(res[1:])

# %%
cs = [[223,116,80], [113,227,143], [51,229,242]]
ns = [[c[0]/255,c[1]/255,c[2]/255] for c in cs]
args = [ns, [5,5,3]]
res = dynamic_color.findPalette(*args)
show_palette(res[len(cs):])

# %%
cs = [[247,174,153], [255,114,110], [255,120,187]]
ns = [[c[0]/255,c[1]/255,c[2]/255] for c in cs]
args = [ns, [4,4,5]]
res = dynamic_color.findPalette(*args)
show_palette(res[len(cs):])
